# %%
from math import *
from random import *
import numpy as np
import matplotlib.pyplot as plt

# %%
#algorithme mtropolis et recuit simulé
from math import *
from random import *
import matplotlib.pyplot as plt
import numpy as np
f=lambda x: x*x-4*x+4


nbiter=100
x1=50 #position initiale
t=100
i=0
xbest=2
n=4
tb=0
L=[]
ntf=5
while (i<ntf):
    for j in range(1000):
        print('cycle: ' + str(i))
        x2=x1+randint(-n,n)
        delta=(f(x2)-f(x1))
        if(delta<0) and accept==True:
            x1=x2           #on accepte le nouvel etat
            gamma=f(xbest)-f(x1)
            if (gamma>0):
                xbest=x1
                accept==True
                
        else:
            if (randint(0,1) < exp(-delta/t)): #probabilité d'accepter le nouvel etat
                x1=x2
                accept=True
                
        i+=1
        print('x1= '+str(x1))
        
t=0.99*t
n=0.99*n
print("la meilleur solution est: ", xbest)



fig=plt.figure()
plt.show()
x = np.linspace(0, 2, 1000)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.

ax.plot(x, x*x-4*x+4, label='f(x)')  # Plot more data on the axes...

ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.
# Out:
# cycle: 0
# x1= 48
# cycle: 1
# x1= 46
# cycle: 2
# x1= 50
# cycle: 3
# x1= 47
# cycle: 4
# x1= 51
# cycle: 5
# x1= 49
# cycle: 6
# x1= 46
# cycle: 7
# x1= 49
# cycle: 8
# x1= 45
# cycle: 9
# x1= 43
# cycle: 10
# x1= 42
# cycle: 11
# x1= 40
# cycle: 12
# x1= 39
# cycle: 13
# x1= 38
# cycle: 14
# x1= 36
# cycle: 15
# x1= 36
# cycle: 16
# x1= 32
# cycle: 17
# x1= 29
# cycle: 18
# x1= 31
# cycle: 19
# x1= 31
# cycle: 20
# x1= 28
# cycle: 21
# x1= 28
# cycle: 22
# x1= 28
# cycle: 23
# x1= 28
# cycle: 24
# x1= 32
# cycle: 25
# x1= 32
# cycle: 26
# x1= 35
# cycle: 27
# x1= 39
# cycle: 28
# x1= 37
# cycle: 29
# x1= 33
# cycle: 30
# x1= 35
# cycle: 31
# x1= 35
# cycle: 32
# x1= 35
# cycle: 33
# x1= 35
# cycle: 34
# x1= 33
# cycle: 35
# x1= 34
# cycle: 36
# x1= 30
# cycle: 37
# x1= 30
# cycle: 38
# x1= 27
# cycle: 39
# x1= 29
# cycle: 40
# x1= 30
# cycle: 41
# x1= 30
# cycle: 42
# x1= 26
# cycle: 43
# x1= 26
# cycle: 44
# x1= 24
# cycle: 45
# x1= 24
# cycle: 46
# x1= 24
# cycle: 47
# x1= 21
# ...
